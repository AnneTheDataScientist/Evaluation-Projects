# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv("avocado.csv",parse_dates=["Date"])
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1             1.0 2015-12-20          1.35      54876.98   674.28   44638.81
# 2             2.0 2015-12-13          0.93     118220.22   794.70  109149.67
# 3             3.0 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4             4.0 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 16463         NaN        NaT           NaN           NaN      NaN        NaN
# 16464         NaN        NaT           NaN           NaN      NaN        NaN
# 16465         NaN        NaT           NaN           NaN      NaN        NaN
# 16466         NaN        NaT           NaN           NaN      NaN        NaN
# 16467         NaN        NaT           NaN           NaN      NaN        NaN
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             float64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                   float64
# region                  object
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1         1.0 2015-12-20          1.35      54876.98   674.28   44638.81
# 2         2.0 2015-12-13          0.93     118220.22   794.70  109149.67
# 3         3.0 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4         4.0 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   datetime64[ns]
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: datetime64[ns](1), float64(11), object(2)
# memory usage: 1.8+ MB

# %%
#Let's check for null values
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
#let's remove blank rows
df=df.dropna()
df
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0 2015-12-27          1.33      64236.62   1036.74   54454.85
# 1            1.0 2015-12-20          1.35      54876.98    674.28   44638.81
# 2            2.0 2015-12-13          0.93     118220.22    794.70  109149.67
# 3            3.0 2015-06-12          1.08      78992.15   1132.00   71976.41
# 4            4.0 2015-11-29          1.28      51039.60    941.48   43838.39
# ...          ...        ...           ...           ...       ...        ...
# 1512        10.0 2016-10-16          1.39     190846.01  57529.11   56366.66
# 1513        11.0 2016-09-10          1.51     178235.75  43325.87   52189.61
# 1514        12.0 2016-02-10          1.48     178410.82  46364.75   52893.38
# 1515        13.0 2016-09-25          1.47     189131.52  54110.79   53593.58
# 1516        14.0 2016-09-18          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
#Let's check if null values are present
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %% [markdown]
# Observation: The color indicates that there are no null values

# %%
#Let's drop the irrelvant columns - Unnamed: 0
df.drop("Unnamed: 0",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-5c893ada4df8> in <module>
#       1 #Let's drop the irrelvant columns - Unnamed: 0
# ----> 2 df.drop("Unnamed: 0",axis=1,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
#Let's check how many types of avocado do we have
df["type"].unique()
# Out:
# array(['conventional'], dtype=object)

# %%
#Since there is only one type of avocado i.e. conventional, lets drop the column as it does not impact the average price
df.drop("type",axis=1,inplace=True)
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags    year  region
# 0     8696.87     8603.62       93.25          0.0  2015.0  Albany
# 1     9505.56     9408.07       97.49          0.0  2015.0  Albany
# 2     8145.35     8042.21      103.14          0.0  2015.0  Albany
# 3     5811.16     5677.40      133.76          0.0  2015.0  Albany
# 4     6183.95     5986.26      197.69          0.0  2015.0  Albany

# %%
#Let's check the unique regions
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids',
#        'GreatLakes', 'HarrisburgScranton', 'HartfordSpringfield',
#        'Houston', 'Indianapolis', 'Jacksonville', 'LasVegas',
#        'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Midsouth',
#        'Nashville', 'NewYork', 'Northeast', 'NorthernNewEngland',
#        'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains',
#        'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
#Let's add a date and month column since we already have the year
df["Day"]=df["Date"].apply(lambda x:x.day)
df["Month"]=df["Date"].apply(lambda x:x.month)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# ...

# %%
#Now we can drop the Date column
df.drop("Date",axis=1,inplace=True)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  region  Day  Month
# 0     8603.62       93.25          0.0  2015.0  Albany   27     12
# 1     9408.07       97.49          0.0  2015.0  Albany   20     12
# ...

# %%
#Let's check our data types 
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# year            float64
# Day               int64
# Month             int64
# dtype: object

# %%
#Let's remove region since we are not going to use it for predicting average price
df.drop("region",axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  Day  Month
# 0     8603.62       93.25          0.0  2015.0   27     12
# 1     9408.07       97.49          0.0  2015.0   20     12
# 2     8042.21      103.14          0.0  2015.0   13     12
# 3     5677.40      133.76          0.0  2015.0   12      6
# 4     5986.26      197.69          0.0  2015.0   29     11

# %%
#Let's check our data types finally
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# year            float64
# Day               int64
# Month             int64
# dtype: object

# %%
#Let's check the correlation
df_corr=df.corr()
df_corr
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
# Day               0.092589     -0.034857 -0.031806 -0.044008 -0.021318
# Month             0.060642     -0.055212 -0.053007 -0.058429 -0.055079
#
# ...

# %%
#Let's check correlation on a heatmap
plt.figure(figsize=(10,4))
sns.heatmap(df_corr,annot=True,cmap="winter")

# %% [markdown]
# Observations:
#
# 1 - Year, Day and Month are highly positively correlated with Average Price
#
# 2 - All others are negatively correlated with Average Price

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year  \
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %% [markdown]
# Observations: Minimum Average Price is 0.49 and Maximum is 1.68

# %%
#Let's see how Average Price is impacted every year
sns.barplot(x="year",y="AveragePrice",data=df)
plt.show()

# %% [markdown]
# Observation:Average Price of Avocado is higher in 2016 as compared to 2015

# %%
#Let's see how Average Price is impacted by Total Bags
sns.set(style="whitegrid")
plt.scatter(df["Total Bags"],df["AveragePrice"])
plt.xlabel("Total Bags")
plt.ylabel("AveragePrice")
plt.show()

# %% [markdown]
# Observation:Average Price is the highest when the Total Bags sold are less than 1000000

# %%
#Let's check the impact of Total Volume on Average Price
sns.lineplot(x="Total Volume",y="AveragePrice",data=df)
plt.show()

# %% [markdown]
# Observation: Price is the highest when the total volume as around 15

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# Day             0.041303
# Month           0.101439
# dtype: float64

# %%
for i in df.columns:
    if df.skew().loc[i]>0.55:
        df[i]=np.log1p(df[i])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# year            1.828332
# Day             0.041303
# Month           0.101439
# dtype: float64

# %%
#Let's check for outliers
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df_final=df.loc[(z_score<3).all(axis=1)]
print(df_final)
# Out:
# (1517, 12)
#       AveragePrice  Total Volume       4046       4225      4770  Total Bags  \
# 0             1.33     11.070344   6.944801  10.905146  3.895080    9.070833
# 1             1.35     10.912867   6.515127  10.706381  4.083115    9.159737
# 2             0.93     11.680313   6.679222  11.600485  4.879007    9.005325
# 3             1.08     11.277116   7.032624  11.184108  4.298373    8.667708
# 4             1.28     10.840377   6.848515  10.688288  4.340944    8.729874
# ...            ...           ...        ...        ...       ...         ...
# 1512          1.39     12.159227  10.960064  10.939651  9.771828   10.992377
# 1513          1.51     12.090868  10.676528  10.862658  9.874088   11.055667
# 1514          1.48     12.091850  10.744316  10.876052  9.725432   11.041589
# 1515          1.47     12.150203  10.898807  10.889203  9.769752   11.065587
# 1516          1.43     12.117128  10.671682  10.900333  9.715042   11.143390
#
# ...

# %% [markdown]
# Observation: 15 outliers removed

# %%
#let's check pairplot
sns.pairplot(df)
plt.show()

# %%
#Let's separate our input and output variables
df_x=df_final.drop(columns=["AveragePrice"])
y=df_final[["AveragePrice"]]

# %%
#Let's scale our input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.skew()
# Out:
# Total Volume    0.592040
# 4046           -0.203940
# 4225            0.122951
# 4770           -0.371693
# Total Bags      0.621617
# Small Bags      0.643635
# Large Bags     -0.934829
# XLarge Bags     0.796336
# year            1.838704
# Day             0.038879
# Month           0.097808
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_rscore=0
for r in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r,test_size=0.20)
    reg=linear_model.LinearRegression()
    reg.fit(x_train,y_train)
    y_pred=reg.predict(x_test)
    r2=r2_score(y_test,y_pred)
    if r2>max_rscore:
        max_rscore=r2
        final_rstate=r
print("Max R2 Score for",final_rstate,"is",max_rscore)
# Out:
# Max R2 Score for 96 is 0.45311709772924746

# %%
#Let's try different algorithms
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for i in model:
    i.fit(x_train,y_train)
    print("Score of",i,"is",i.score(x_train,y_train))
    predi=i.predict(x_test)
    print("Error:")
    print("Mean Abs Error ",mean_absolute_error(y_test,predi))
    print("Mean Squared Error ",mean_squared_error(y_test,predi))
    print("RMSE ",np.sqrt(mean_squared_error(y_test,predi)))
    print("r2_score",r2_score(y_test,predi))
    print("\n")
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.3840283599199522
# Error:
# Mean Abs Error  0.11885381773421509
# Mean Squared Error  0.021994993982846635
# RMSE  0.14830709350144597
# r2_score 0.42038853144584865
#
#
# Score of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') is 1.0
# Error:
# Mean Abs Error  0.07966777408637875
# Mean Squared Error  0.014084385382059804
# RMSE  0.11867765325477161
# r2_score 0.6288486688677979
#
#
# Score of KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
# ...

# %%
#Let's choose the Ridge model and find the parameters
from sklearn.model_selection import GridSearchCV
ridge=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1],"random_state":range(42,100)}
clf=GridSearchCV(ridge,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1, 'random_state': 42}

# %%
ridge=Ridge(alpha=1,random_state=42)
ridge.fit(x_train,y_train)
print("Score:",ridge.score(x_train,y_train))
predrdg=ridge.predict(x_test)
print("Error:")
print("Mean Abs Error ",mean_absolute_error(y_test,predrdg))
print("Mean Squared Error ",mean_squared_error(y_test,predrdg))
print("RMSE ",np.sqrt(mean_squared_error(y_test,predrdg)))
print("r2_score",r2_score(y_test,predrdg))
# Out:
# Score: 0.3837992889569316
# Error:
# Mean Abs Error  0.11885545482682325
# Mean Squared Error  0.02200485994341765
# RMSE  0.1483403517031615
# r2_score 0.4201285439277924

# %%
#Cross Validating the model
score=cross_val_score(ridge,x,y,cv=4,scoring="r2")
print("Score ",score)
print("Mean Score ",score.mean())
print("Standard Dev ",score.std())
# Out:
# Score  [-0.08119765 -0.0057375   0.25143673  0.19966146]
# Mean Score  0.09104075978815263
# Standard Dev  0.1383450616739117

# %%
#Let's use Random Forest to boost the score
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=20,random_state=60)
rf.fit(x_train,y_train)
print("Score ",rf.score(x_train,y_train))
predrf=rf.predict(x_test)
print("\n")
print("Mean Abs Error ",mean_absolute_error(y_test,predrf))
print("Mean Squared Error ",mean_squared_error(y_test,predrf))
print("RMSE ",np.sqrt(mean_squared_error(y_test,predrf)))
print("r2_score",r2_score(y_test,predrf))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Score  0.9640665368314876
#
#
# Mean Abs Error  0.06550664451827244
# Mean Squared Error  0.007934630398671098
# RMSE  0.08907654235920419
# r2_score 0.7909068408295625

# %%
#Let's save the RandomForest Regressor
from sklearn.externals import joblib
joblib.dump(rf,"Avocado.pkl")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['Avocado.pkl']
